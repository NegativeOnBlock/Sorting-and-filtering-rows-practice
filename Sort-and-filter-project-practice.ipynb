# %%
import pandas as pd 
vehicles = pd.read_csv('light-duty-vehicles-2023-11-09.csv')
vehicles.head()
# Out:
#    Vehicle ID  Fuel ID  Fuel Configuration ID  Manufacturer ID  Category ID  \
# 0       13532       57                    9.0              490           29
# 1       13483       45                    9.0              377           27
# 2       13482       45                    9.0              377           27
# 3       13347       45                    9.0              377           27
# 4       13348       45                    9.0              377           27
#
#                                   Model  Model Year  \
# 0                           Tonale eAWD        2024
# 1                                    A3        2024
# 2                            A3 quattro        2024
# 3             A4 quattro/S-Line/Allroad        2024
# 4  A5 quattro Coupe/Cabriolet/Sportback        2024
#
#    Alternative Fuel Economy City  Alternative Fuel Economy Highway  \
# 0                            NaN                               NaN
# ...

# %% [markdown]
# # Row Indexes

# %%
vehicles.index
# Out:
# RangeIndex(start=0, stop=3435, step=1)

# %%
model_counts = vehicles['Model'].value_counts()
model_counts.index
# Out:
# Index(['F-150', 'Savana 2500', 'Taurus FFV', 'Express 2500', 'Prius',
#        'Silverado', 'Insight', 'Impala', 'Civic GX', 'Super Duty F-250',
#        ...
#        'Model S RWD 60 kWh', 'Yukon/Yukon XL 4WD',
#        'e-tron Sportback/S Sportback',
#        'Tahoe Police & Special Service Vehicle', 'i7 M70 xDrive Sedan',
#        'Grand Cherokee', 'Armada, 2WD/4WD', 'SF90 Spider',
#        'AMG GLE 53 4MATIC+ (Coupe)', 'Savana, Cutaway 4500'],
#       dtype='object', length=1480)

# %%
model_counts = vehicles['Model'].value_counts()
model_counts_reset = model_counts.reset_index()
model_counts_reset
# Out:
#                            index  Model
# 0                          F-150     36
# 1                    Savana 2500     18
# 2                     Taurus FFV     17
# 3                   Express 2500     16
# 4                          Prius     15
# ...                          ...    ...
# 1475              Grand Cherokee      1
# 1476             Armada, 2WD/4WD      1
# 1477                 SF90 Spider      1
# 1478  AMG GLE 53 4MATIC+ (Coupe)      1
# 1479        Savana, Cutaway 4500      1
#
# [1480 rows x 2 columns]

# %% [markdown]
# # Sorting Rows

# %%
vehicles = vehicles.sort_values(by='Model Year')
vehicles.head()
# Out:
#       Vehicle ID  Fuel ID  Fuel Configuration ID  Manufacturer ID  \
# 3434         649       49                    5.0              219
# 3433         650       49                    5.0              215
# 3431         660       49                    5.0              225
# 3430         656        3                    1.0              225
# 3429         651       11                    5.0              215
#
#       Category ID         Model  Model Year  Alternative Fuel Economy City  \
# 3434           27    Taurus FFV        1991                           14.0
# 3433           27    Lumina FFV        1991                            NaN
# 3431           27    Spirit FFV        1992                            NaN
# 3430            9  Ram Van B250        1992                            NaN
# 3429           27    Lumina FFV        1992                            NaN
#
#       Alternative Fuel Economy Highway Alternative Fuel Economy Combined  ...  \
# ...

# %%
vehicles= vehicles.sort_values(by='Seating Capacity', ascending=False)
vehicles.head()
# Out:
#      Vehicle ID  Fuel ID  Fuel Configuration ID  Manufacturer ID  Category ID  \
# 372       13396       41                    1.0              470           29
# 371       13319       41                    1.0              470           29
# 230       13290       57                    9.0              223            9
# 317       13296       57                    9.0              227           29
# 63        13530       57                    9.0              223            9
#
#                 Model  Model Year  Alternative Fuel Economy City  \
# 372    R1S Dual Motor        2023                            NaN
# 371               R1S        2023                            NaN
# 230   Pacifica Hybrid        2023                            NaN
# 317  Aviator AWD PHEV        2023                            NaN
# 63    Pacifica Hybrid        2024                            NaN
#
#      Alternative Fuel Economy Highway Alternative Fuel Economy Combined  ...  \
# ...

# %%
year_counts = vehicles['Model Year'].value_counts()
year_counts = year_counts = year_counts.sort_index()
year_counts
# Out:
# 1991      2
# 1992      5
# 1993      7
# 1994      5
# 1995     13
# 1996     12
# 1997     17
# 1998     25
# 1999     43
# 2000     39
# 2001     44
# 2002     48
# 2003     47
# 2004     40
# 2005     37
# 2006     36
# 2007     46
# 2008     50
# 2009     59
# 2010     57
# 2011    117
# 2012    123
# 2013    162
# 2014    195
# 2015    192
# 2016    158
# 2017    183
# 2018    204
# 2019    220
# 2020    228
# 2021    274
# 2022    325
# 2023    258
# 2024    164
# Name: Model Year, dtype: int64

# %% [markdown]
# # Selecting Specific Rows

# %%
model_2023 = vehicles.loc[[1960,2023], ['Model']]
model_2023
# Out:
#                        Model
# 1960  Grand Cherokee 2WD/FWD
# 2023         Continental GTC

# %%
alt_Fuel_Eco_City_2023 = vehicles.iloc[[0,1],[6]]
alt_Fuel_Eco_City_2023
# Out:
#      Model Year
# 372        2023
# 371        2023

# %% [markdown]
# # Selecting Ranges of Rows

# %%
sliced=vehicles.iloc[0:4, 5:7]

sliced
# Out:
#                        Model  Model Year
# 0                Tonale eAWD        2024
# 1                         A3        2024
# 2                 A3 quattro        2024
# 3  A4 quattro/S-Line/Allroad        2024

# %%
quattros = vehicles.loc[2:3, 'Model':'Model Year']

quattros
# Out:
#                        Model  Model Year
# 2                 A3 quattro        2024
# 3  A4 quattro/S-Line/Allroad        2024

# %%
large_slice = vehicles.iloc[:15, 5:]
large_slice
# Out:
#                                    Model  Model Year  \
# 0                            Tonale eAWD        2024
# 1                                     A3        2024
# 2                             A3 quattro        2024
# 3              A4 quattro/S-Line/Allroad        2024
# 4   A5 quattro Coupe/Cabriolet/Sportback        2024
# 5                             A6 quattro        2024
# 6                     A6 quattro/Allroad        2024
# 7                             A7 quattro        2024
# 8                             A8 quattro        2024
# 9                 e-tron GT/RS e-tron GT        2024
# 10                          Q4 40 e-tron        2024
# 11                  Q4 50 e-tron quattro        2024
# 12        Q4 Sportback 50 e-tron quattro        2024
# 13           Q5 quattro/Sportback/S-Line        2024
# 14                            Q7 quattro        2024
#
#     Alternative Fuel Economy City  Alternative Fuel Economy Highway  \
# ...

# %% [markdown]
# # Booleans

# %%
car_transmissiontype = vehicles['Transmission Type'] == 'Auto'

car_transmissiontype.head(10)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Transmission Type, dtype: bool

# %%
is_1998 = (vehicles['Model Year'] == 1998)
is_1998.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Model Year, dtype: bool

# %%
vehicles[is_1998]
#or 
#vehicles[vehicles['Model Year'] == 1999]
# Out:
#       Vehicle ID  Fuel ID  Fuel Configuration ID  Manufacturer ID  \
# 3349           4        3                    3.0              215
# 3350          10        3                    3.0              215
# 3351          12       41                    1.0              215
# 3352          11       41                    1.0              215
# 3353           8       11                    5.0              225
# 3354          13        3                    3.0              219
# 3355           7        3                    1.0              219
# 3356          20        3                    3.0              219
# 3357          21       55                    3.0              219
# 3358          19        3                    1.0              219
# 3359          18        3                    1.0              219
# 3360           6        3                    3.0              219
# 3361          17       55                    3.0              219
# ...

# %%
is_2023 = vehicles['Model Year'] == 2023
is_low_Alternative_Fuel_Economy_City = vehicles['Alternative Fuel Economy City'] <= 12
low_alt_fuel_forcity_2023 = vehicles[is_2023 & is_low_Alternative_Fuel_Economy_City]
low_alt_fuel_forcity_2023.head()
# Out:
#      Vehicle ID  Fuel ID  Fuel Configuration ID  Manufacturer ID  Category ID  \
# 223       13135       11                    5.0              215           25
# 224       13136       11                    5.0              215           25
# 260       13137       11                    5.0              213           25
# 262       13138       11                    5.0              213           25
#
#              Model  Model Year  Alternative Fuel Economy City  \
# 223  Silverado 2WD        2023                           12.0
# 224  Silverado 4WD        2023                           11.0
# 260     Sierra 2WD        2023                           12.0
# 262     Sierra 4WD        2023                           11.0
#
#      Alternative Fuel Economy Highway Alternative Fuel Economy Combined  ...  \
# 223                              15.0                                13  ...
# 224                              14.0                                12  ...
# ...
